# %% [markdown]
# # SAMPLE/DEMO

# %%
import pandas as pd
import re

# %%
df = pd.read_csv("sample_done.csv")
df['source'] = 'serjeant'
df['type_of_entry'] = 'in'
df['unique_ID'] = ''
PLUS_PATTERN = r'\+[0-9.]*'

df
# Out:
#     entry_#                                   SMILES pka_type  pka_value  \
# 0      2004                                       CO      pKa      15.50
# 1      2004                                       CO      pKa      15.09
# 2      2005                                      COO      pKa      11.50
# 3      2006                                       CS      pKa      10.33
# 4      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pKa       0.14
# 5      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pKa       0.06
# 6      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pKa       0.05
# 7      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pKa       0.23
# 8      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pKa       0.17
# 9      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pKa       0.11
# 10     2008                O=[N+]([O-])C[N+](=O)[O-]      pKa       3.63
# 11     2008                O=[N+]([O-])C[N+](=O)[O-]      pKa       3.72
# 12     2008                O=[N+]([O-])C[N+](=O)[O-]      pKa       3.60
# 13     2008                O=[N+]([O-])C[N+](=O)[O-]      pKa       3.51
# 14     2008                O=[N+]([O-])C[N+](=O)[O-]      pKa       3.43
# 15     2008                O=[N+]([O-])C[N+](=O)[O-]      pKa       3.57
# 16     2009                            C[N+](=O)[O-]      pKa      10.45
# 17     2009                            C[N+](=O)[O-]      pKa      10.33
# 18     2009                            C[N+](=O)[O-]      pKa      10.21
# 19     2009                            C[N+](=O)[O-]      pKa      10.24
# 20     2010                                      NaN      pKa       8.65
# 21     2011                                  NC(=S)S      pKa       2.95
# 22     2012                                 O=S(O)CO      pKa       1.65
#
#        T                            remarks method assessment       ref  \
# 0   25.0                                NaN     C3    Uncert.        B8
# 1   25.0                                NaN    KIN    Uncert.      M126
# 2   20.0                                NaN     O5    Uncert.       E27
# 3   25.0  1% ethanol, gas solubility method    NaN    Uncert.       K57
# 4   20.0          In aqueous HClO4 Ho scale     O6    Uncert.      T58a
# 5   25.5                     Mixed constant     O5    Uncert.        H5
# 6    9.6                     Mixed constant     O5    Uncert.        H5
# 7    5.0            In aqueous HCl Ho scale     O6    Uncert.  N39, S82
# 8   20.0            In aqueous HCl Ho scale     O6    Uncert.  N39, S82
# 9   40.0            In aqueous HCl Ho scale     O6    Uncert.  N39, S82
# 10  20.0                             I=0.06     O5    Approx.       N39
# 11   5.0                             I=0.06     O5    Approx.       N39
# 12  20.0                             I=0.06     O5    Approx.       N39
# 13  40.0                             I=0.06     O5    Approx.       N39
# 14  60.0                             I=0.06     O5    Approx.       N39
# 15  25.0                             I=0.06     O5    Approx.        A7
# 16  10.0      c=0.005-0.017, mixed constant   E3bg    Approx.       T67
# 17  18.0      c=0.005-0.017, mixed constant   E3bg    Approx.       T67
# 18  25.0      c=0.005-0.017, mixed constant   E3bg    Approx.       T67
# 19  25.0      c=0.005-0.017, mixed constant   E3bg    Approx.       W22
# 20   NaN                        I=0.2(NaCl)   E3bg    Uncert.       C72
# 21  25.0                       c=0.002-0.01     C2    Approx.        G4
# 22  20.0              c=0.1, mixed constant   E3bg    Approx.       R54
#
#                                           ref_remarks  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   Thermodynamic quantities are derived from the ...
# 8   Thermodynamic quantities are derived from the ...
# 9   Thermodynamic quantities are derived from the ...
# 10  Thermodynamic quantities are derived from the ...
# 11  Thermodynamic quantities are derived from the ...
# 12  Thermodynamic quantities are derived from the ...
# 13  Thermodynamic quantities are derived from the ...
# 14  Thermodynamic quantities are derived from the ...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                         entry_remarks  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4    - 0.02  Thermodynamic quantities are derived ...
# 5    - 0.02  Thermodynamic quantities are derived ...
# 6    - 0.02  Thermodynamic quantities are derived ...
# 7    - 0.02  Thermodynamic quantities are derived ...
# 8    - 0.02  Thermodynamic quantities are derived ...
# 9    - 0.02  Thermodynamic quantities are derived ...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#               original_IUPAC_names original_IUPAC_nicknames  \
# 0                         Methanol                      NaN
# 1                         Methanol                      NaN
# 2             Methyl hydroperoxide                      NaN
# 3                     Methanethiol                      NaN
# 4               methane, trinitro-                      NaN
# 5               methane, trinitro-                      NaN
# 6               methane, trinitro-                      NaN
# 7               methane, trinitro-                      NaN
# 8               methane, trinitro-                      NaN
# 9               methane, trinitro-                      NaN
# 10               methane, dinitro-                      NaN
# 11               methane, dinitro-                      NaN
# 12               methane, dinitro-                      NaN
# 13               methane, dinitro-                      NaN
# 14               methane, dinitro-                      NaN
# 15               methane, dinitro-                      NaN
# 16                 methane, nitro-                      NaN
# 17                 methane, nitro-                      NaN
# 18                 methane, nitro-                      NaN
# 19                 methane, nitro-                      NaN
# 20          Methanohydroxamic acid     Formohydroxamic acid
# 21    methanedithioic acid, amino-      Dithiocarbamic acid
# 22  methanesulfinic acid, hydroxy-                      NaN
#
#                                     name_contributors  num_name_contributors  \
# 0     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 1     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 2     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 3     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 4     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 5     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 6     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 7     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 8     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 9     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 10    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 11    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 12    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 13    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 14    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 15    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 16    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 17    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 18    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 19    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 20                                                NaN                    NaN
# 21  ['opsin_name1', 'opsin_nickname1', 'pubchem_ni...                    3.0
# 22                                    ['opsin_name1']                    1.0
#
#       source type_of_entry unique_ID
# 0   serjeant            in
# 1   serjeant            in
# 2   serjeant            in
# 3   serjeant            in
# 4   serjeant            in
# 5   serjeant            in
# 6   serjeant            in
# 7   serjeant            in
# 8   serjeant            in
# 9   serjeant            in
# 10  serjeant            in
# 11  serjeant            in
# 12  serjeant            in
# 13  serjeant            in
# 14  serjeant            in
# 15  serjeant            in
# 16  serjeant            in
# 17  serjeant            in
# 18  serjeant            in
# 19  serjeant            in
# 20  serjeant            in
# 21  serjeant            in
# 22  serjeant            in

# %% [markdown]
# ### Clean up all entries

# %%
P_MATCH = r"P=[0-9]*[a-z ().]*"

pka_replacements = [
    ('pk', 'pK'),
    ('pka', 'pK1'),
    ('pKa', 'pK1'),
    ('cooh', 'COOH'),
    ('pKa(H2O)', 'pK1'),
    ('pK1(H2O)', 'pK1'),
    ('pK2(H2O)', 'pK2'),
    ('pK3(H2O)', 'pK3'),
    ('pKb', 'pKB')
]

def fix_pka_type(entry, source):
    """
    Fix/reformats several pKa types in the dataset and returns the reformatted entry.
    Works differently based on the reference source.
    """
    if pd.isnull(entry):
        return entry
    else:
        for replacement in pka_replacements:
            entry = entry.replace(replacement[0], replacement[1])
            
        if 'pK(' in entry and (source == 'perrin' or source == 'perrin_supp'): # as Perrin and Perrin Supp. are for basic pK's.
            entry = entry.replace('pK(', 'pKAH(')
        
        return entry

remarks_replacements = [
    ('\n. ', ''),
    ('( (', '('),
    ('( ', '('),
    (' )', ')'),
    ('c = ', 'C='),
    ('c =', 'C='),
    ('c= ', 'C='),
    ('c=', 'C='),
    ('c~', 'C~'),
    ('c<', 'C<'),
    ('c <', 'C<'),
    ('c < ', 'C<'),
    ('C = ', 'C='),
    ('c - ', 'C='),
    ('C= ', 'C='),
    ('C =', 'C='),
    ('concentration\nconstant', 'concentration constant'),
    ('concentration, constant', 'concentration constant'),
    ('I = ', 'I='),
    ('I =', 'I='),
    ('I= ', 'I='),
    ('m = ', 'm='),
    ('m= ', 'm='),
    ('m =', 'm='),
    ('C< ', 'C<'),
    ('C <', 'C<'),
    ('C < ', 'C<'),
    ('I< ', 'I<'),
    ('1m solution', '1M solution'),
    ('I <', 'I<'),
    ('I < ', 'I<'),
    ('S04', 'SO4'),
    ('KCI', 'KCl'),
    ('DCI', 'DCl'),
    ('c between', 'C between'),
    ('HCI', 'HCl'),
    ('NaCI', 'NaCl'),
    ('from, thermo', 'from thermo'),
    (' (KCl)', ' (KCl)'),
    (' (HCl', ' (HCl'),
    (' (KBr)', ' (KBr)'),
    (' (K2SO4)', '(K2SO4)'),
    (' (NaClO4)', '(NaClO4)'),
    (' (KNO3)', '(KNO3)'),
    (' (NaCl)', '(NaCl)'),
    (',,', ','),
    ('()', ''),
    ('. mixed', ', mixed'),
    (': mixed', ', mixed'),
    (') mixed', '), mixed'),
    ('. conc', ', conc'),
    (') conc', '), conc'),
    ('\n\n\n', '\n')
]

def fix_remarks(entry):
    """
    Fix some additional common mistakes that were found in the data, and returns the reformatted entry.
    """
    if pd.isnull(entry):
        return entry
    else:
        for replacement in remarks_replacements:
            entry = entry.replace(replacement[0], replacement[1])
    
        return entry

def fix_entry_remarks(entry):
    """Fixes typos in an entry's remarks, and returns the fixed entry."""
    if pd.isnull(entry):
        return entry
    else:
        entry = entry.replace('- Thermodynamic data are derived from the results','')
        entry = entry.strip('.\n ')
        entry = entry.replace('- \n', ' - ')
        return entry

def fix_ref_remarks(entry):
    """Fixes typos in an entry's references, eliminating trailing semicolons, and returns the fixed entry."""
    if pd.isnull(entry):
        return entry
    else:
        entry = entry.strip('; ')
        return entry

def isolate_P(entry):
    """Finds pressure in an entry's remark if it is available. Returns P if found, otherwise returns None."""
    if pd.isnull(entry):
        return None
    match = re.search(P_MATCH,entry)
    if match:
        return match.group().replace('P=','')
    return None

def standardize_refs(entry):
    """Fixes typos in an entry's refs by stripping trailing spaces, and returns the fixed entry."""    
    if pd.isnull(entry):
        return entry
    return entry.strip()

def standardize_assessment(entry):
    """Fixes typos in an entry's uncertainty assessments, and returns the fixed entry."""

    if pd.isnull(entry):
        return entry
    entry = entry.replace('.','')
    entry = entry.replace('Approx','Approximate')
    entry = entry.replace('approx','approximate')
    if entry == 'Uncert':
        entry = 'Uncertain'
    entry = entry.replace('Rel','Reliable')
    entry = entry.replace('Very Uncertain','Very uncertain')
    entry = entry.replace('Very Uncert','Very uncertain')
    entry = entry.replace('V Uncert','Very uncertain')
    entry = entry.replace('VUncert','Very uncertain')
    entry = entry.replace('Vuncert','Very uncertain')
    if entry == 'Very uncert':
        entry = 'Very uncertain'
    return entry
    
def make_acidity_label(entry, source) -> str:
    """
    Given an entry and its original reference text source, returns a label that assesses whether the pKa entry
    is for an acidic pK or a basic one. AH = conjugate acid, A = acid, B = base.
    """
    if pd.isnull(entry):
        return None
    if 'pKAH' in entry:
        return 'AH'
    elif 'pKB' in entry or source == 'perrin' or source == 'perrin_supp':
        return 'B'
    else:
        return 'A'
    
df['remarks'] = df['remarks'].apply(lambda x: fix_remarks(x))
df['entry_remarks'] = df['entry_remarks'].apply(lambda x: fix_entry_remarks(x))
df['ref_remarks'] = df['ref_remarks'].apply(lambda x: fix_ref_remarks(x))
df['pka_type'] = df.apply(lambda x: fix_pka_type(x.pka_type, x.source), axis=1)
df['pressure'] = df['remarks'].apply(lambda x: isolate_P(x))
df['ref'] = df['ref'].apply(lambda x: standardize_refs(x))
df['assessment'] = df['assessment'].apply(lambda x: standardize_assessment(x))
df['acidity_label'] = df.apply(lambda x: make_acidity_label(x.pka_type, x.source), axis=1)

df.to_csv("all_cat.csv",index=False)
df
# Out:
#     entry_#                                   SMILES pka_type  pka_value  \
# 0      2004                                       CO      pK1      15.50
# 1      2004                                       CO      pK1      15.09
# 2      2005                                      COO      pK1      11.50
# 3      2006                                       CS      pK1      10.33
# 4      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.14
# 5      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.06
# 6      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.05
# 7      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.23
# 8      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.17
# 9      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.11
# 10     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.63
# 11     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.72
# 12     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.60
# 13     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.51
# 14     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.43
# 15     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.57
# 16     2009                            C[N+](=O)[O-]      pK1      10.45
# 17     2009                            C[N+](=O)[O-]      pK1      10.33
# 18     2009                            C[N+](=O)[O-]      pK1      10.21
# 19     2009                            C[N+](=O)[O-]      pK1      10.24
# 20     2010                                      NaN      pK1       8.65
# 21     2011                                  NC(=S)S      pK1       2.95
# 22     2012                                 O=S(O)CO      pK1       1.65
#
#        T                            remarks method   assessment       ref  \
# 0   25.0                                NaN     C3    Uncertain        B8
# 1   25.0                                NaN    KIN    Uncertain      M126
# 2   20.0                                NaN     O5    Uncertain       E27
# 3   25.0  1% ethanol, gas solubility method    NaN    Uncertain       K57
# 4   20.0          In aqueous HClO4 Ho scale     O6    Uncertain      T58a
# 5   25.5                     Mixed constant     O5    Uncertain        H5
# 6    9.6                     Mixed constant     O5    Uncertain        H5
# 7    5.0            In aqueous HCl Ho scale     O6    Uncertain  N39, S82
# 8   20.0            In aqueous HCl Ho scale     O6    Uncertain  N39, S82
# 9   40.0            In aqueous HCl Ho scale     O6    Uncertain  N39, S82
# 10  20.0                             I=0.06     O5  Approximate       N39
# 11   5.0                             I=0.06     O5  Approximate       N39
# 12  20.0                             I=0.06     O5  Approximate       N39
# 13  40.0                             I=0.06     O5  Approximate       N39
# 14  60.0                             I=0.06     O5  Approximate       N39
# 15  25.0                             I=0.06     O5  Approximate        A7
# 16  10.0      C=0.005-0.017, mixed constant   E3bg  Approximate       T67
# 17  18.0      C=0.005-0.017, mixed constant   E3bg  Approximate       T67
# 18  25.0      C=0.005-0.017, mixed constant   E3bg  Approximate       T67
# 19  25.0      C=0.005-0.017, mixed constant   E3bg  Approximate       W22
# 20   NaN                        I=0.2(NaCl)   E3bg    Uncertain       C72
# 21  25.0                       C=0.002-0.01     C2  Approximate        G4
# 22  20.0              C=0.1, mixed constant   E3bg  Approximate       R54
#
#                                           ref_remarks  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   Thermodynamic quantities are derived from the ...
# 8   Thermodynamic quantities are derived from the ...
# 9   Thermodynamic quantities are derived from the ...
# 10  Thermodynamic quantities are derived from the ...
# 11  Thermodynamic quantities are derived from the ...
# 12  Thermodynamic quantities are derived from the ...
# 13  Thermodynamic quantities are derived from the ...
# 14  Thermodynamic quantities are derived from the ...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                         entry_remarks  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   - 0.02  Thermodynamic quantities are derived f...
# 5   - 0.02  Thermodynamic quantities are derived f...
# 6   - 0.02  Thermodynamic quantities are derived f...
# 7   - 0.02  Thermodynamic quantities are derived f...
# 8   - 0.02  Thermodynamic quantities are derived f...
# 9   - 0.02  Thermodynamic quantities are derived f...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#               original_IUPAC_names original_IUPAC_nicknames  \
# 0                         Methanol                      NaN
# 1                         Methanol                      NaN
# 2             Methyl hydroperoxide                      NaN
# 3                     Methanethiol                      NaN
# 4               methane, trinitro-                      NaN
# 5               methane, trinitro-                      NaN
# 6               methane, trinitro-                      NaN
# 7               methane, trinitro-                      NaN
# 8               methane, trinitro-                      NaN
# 9               methane, trinitro-                      NaN
# 10               methane, dinitro-                      NaN
# 11               methane, dinitro-                      NaN
# 12               methane, dinitro-                      NaN
# 13               methane, dinitro-                      NaN
# 14               methane, dinitro-                      NaN
# 15               methane, dinitro-                      NaN
# 16                 methane, nitro-                      NaN
# 17                 methane, nitro-                      NaN
# 18                 methane, nitro-                      NaN
# 19                 methane, nitro-                      NaN
# 20          Methanohydroxamic acid     Formohydroxamic acid
# 21    methanedithioic acid, amino-      Dithiocarbamic acid
# 22  methanesulfinic acid, hydroxy-                      NaN
#
#                                     name_contributors  num_name_contributors  \
# 0     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 1     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 2     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 3     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 4     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 5     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 6     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 7     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 8     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 9     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 10    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 11    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 12    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 13    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 14    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 15    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 16    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 17    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 18    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 19    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 20                                                NaN                    NaN
# 21  ['opsin_name1', 'opsin_nickname1', 'pubchem_ni...                    3.0
# 22                                    ['opsin_name1']                    1.0
#
#       source type_of_entry unique_ID pressure acidity_label
# 0   serjeant            in               None             A
# 1   serjeant            in               None             A
# 2   serjeant            in               None             A
# 3   serjeant            in               None             A
# 4   serjeant            in               None             A
# 5   serjeant            in               None             A
# 6   serjeant            in               None             A
# 7   serjeant            in               None             A
# 8   serjeant            in               None             A
# 9   serjeant            in               None             A
# 10  serjeant            in               None             A
# 11  serjeant            in               None             A
# 12  serjeant            in               None             A
# 13  serjeant            in               None             A
# 14  serjeant            in               None             A
# 15  serjeant            in               None             A
# 16  serjeant            in               None             A
# 17  serjeant            in               None             A
# 18  serjeant            in               None             A
# 19  serjeant            in               None             A
# 20  serjeant            in               None             A
# 21  serjeant            in               None             A
# 22  serjeant            in               None             A

# %% [markdown]
# ### clean up and just get specific types of data

# %%
# An example of filtering the dataframe
for ct, row in df.iterrows():
    nullsmiles = False
    unique_id = row['source'] + str(row['entry_#'])
    df.loc[ct,'unique_ID'] = unique_id
    pka = row['pka_value']
    
    try:
        '.' in row['SMILES'] # can also add code here that checks if the SMILES is a salt with a period in it.
    except TypeError:
        print(">> Dropping N/A smiles")
        df.loc[ct,'type_of_entry'] = 'out' # Basically filter out the entry if it's not a str.
# Out:
# >> Dropping N/A smiles

# %%
# Isolate the DF to all the entries with converged SMILES
# (High and medium confidence values.)
in_df = df.loc[df['type_of_entry'] == 'in']
in_df = in_df.drop(['type_of_entry'],axis=1)

# Isolate the DF to only the entries with converged SMILES and also multiple translation sources that agree.
# (High-confidence).
in_df_2 = df.loc[(df['type_of_entry'] == 'in') & (df['num_name_contributors'] >= 2)]
in_df_2 = in_df_2.drop(['type_of_entry'],axis=1)

# Isolate the DF to only the entries that did NOT converge. These are
out_df = df.loc[df['type_of_entry'] == 'out']
out_df = out_df.drop(['type_of_entry'],axis=1)

# %%
in_df
# Out:
#     entry_#                                   SMILES pka_type  pka_value  \
# 0      2004                                       CO      pK1      15.50
# 1      2004                                       CO      pK1      15.09
# 2      2005                                      COO      pK1      11.50
# 3      2006                                       CS      pK1      10.33
# 4      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.14
# 5      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.06
# 6      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.05
# 7      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.23
# 8      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.17
# 9      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.11
# 10     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.63
# 11     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.72
# 12     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.60
# 13     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.51
# 14     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.43
# 15     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.57
# 16     2009                            C[N+](=O)[O-]      pK1      10.45
# 17     2009                            C[N+](=O)[O-]      pK1      10.33
# 18     2009                            C[N+](=O)[O-]      pK1      10.21
# 19     2009                            C[N+](=O)[O-]      pK1      10.24
# 21     2011                                  NC(=S)S      pK1       2.95
# 22     2012                                 O=S(O)CO      pK1       1.65
#
#        T                            remarks method   assessment       ref  \
# 0   25.0                                NaN     C3    Uncertain        B8
# 1   25.0                                NaN    KIN    Uncertain      M126
# 2   20.0                                NaN     O5    Uncertain       E27
# 3   25.0  1% ethanol, gas solubility method    NaN    Uncertain       K57
# 4   20.0          In aqueous HClO4 Ho scale     O6    Uncertain      T58a
# 5   25.5                     Mixed constant     O5    Uncertain        H5
# 6    9.6                     Mixed constant     O5    Uncertain        H5
# 7    5.0            In aqueous HCl Ho scale     O6    Uncertain  N39, S82
# 8   20.0            In aqueous HCl Ho scale     O6    Uncertain  N39, S82
# 9   40.0            In aqueous HCl Ho scale     O6    Uncertain  N39, S82
# 10  20.0                             I=0.06     O5  Approximate       N39
# 11   5.0                             I=0.06     O5  Approximate       N39
# 12  20.0                             I=0.06     O5  Approximate       N39
# 13  40.0                             I=0.06     O5  Approximate       N39
# 14  60.0                             I=0.06     O5  Approximate       N39
# 15  25.0                             I=0.06     O5  Approximate        A7
# 16  10.0      C=0.005-0.017, mixed constant   E3bg  Approximate       T67
# 17  18.0      C=0.005-0.017, mixed constant   E3bg  Approximate       T67
# 18  25.0      C=0.005-0.017, mixed constant   E3bg  Approximate       T67
# 19  25.0      C=0.005-0.017, mixed constant   E3bg  Approximate       W22
# 21  25.0                       C=0.002-0.01     C2  Approximate        G4
# 22  20.0              C=0.1, mixed constant   E3bg  Approximate       R54
#
#                                           ref_remarks  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   Thermodynamic quantities are derived from the ...
# 8   Thermodynamic quantities are derived from the ...
# 9   Thermodynamic quantities are derived from the ...
# 10  Thermodynamic quantities are derived from the ...
# 11  Thermodynamic quantities are derived from the ...
# 12  Thermodynamic quantities are derived from the ...
# 13  Thermodynamic quantities are derived from the ...
# 14  Thermodynamic quantities are derived from the ...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                         entry_remarks  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   - 0.02  Thermodynamic quantities are derived f...
# 5   - 0.02  Thermodynamic quantities are derived f...
# 6   - 0.02  Thermodynamic quantities are derived f...
# 7   - 0.02  Thermodynamic quantities are derived f...
# 8   - 0.02  Thermodynamic quantities are derived f...
# 9   - 0.02  Thermodynamic quantities are derived f...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#               original_IUPAC_names original_IUPAC_nicknames  \
# 0                         Methanol                      NaN
# 1                         Methanol                      NaN
# 2             Methyl hydroperoxide                      NaN
# 3                     Methanethiol                      NaN
# 4               methane, trinitro-                      NaN
# 5               methane, trinitro-                      NaN
# 6               methane, trinitro-                      NaN
# 7               methane, trinitro-                      NaN
# 8               methane, trinitro-                      NaN
# 9               methane, trinitro-                      NaN
# 10               methane, dinitro-                      NaN
# 11               methane, dinitro-                      NaN
# 12               methane, dinitro-                      NaN
# 13               methane, dinitro-                      NaN
# 14               methane, dinitro-                      NaN
# 15               methane, dinitro-                      NaN
# 16                 methane, nitro-                      NaN
# 17                 methane, nitro-                      NaN
# 18                 methane, nitro-                      NaN
# 19                 methane, nitro-                      NaN
# 21    methanedithioic acid, amino-      Dithiocarbamic acid
# 22  methanesulfinic acid, hydroxy-                      NaN
#
#                                     name_contributors  num_name_contributors  \
# 0     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 1     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 2     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 3     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 4     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 5     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 6     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 7     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 8     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 9     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 10    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 11    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 12    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 13    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 14    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 15    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 16    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 17    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 18    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 19    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 21  ['opsin_name1', 'opsin_nickname1', 'pubchem_ni...                    3.0
# 22                                    ['opsin_name1']                    1.0
#
#       source     unique_ID pressure acidity_label
# 0   serjeant  serjeant2004     None             A
# 1   serjeant  serjeant2004     None             A
# 2   serjeant  serjeant2005     None             A
# 3   serjeant  serjeant2006     None             A
# 4   serjeant  serjeant2007     None             A
# 5   serjeant  serjeant2007     None             A
# 6   serjeant  serjeant2007     None             A
# 7   serjeant  serjeant2007     None             A
# 8   serjeant  serjeant2007     None             A
# 9   serjeant  serjeant2007     None             A
# 10  serjeant  serjeant2008     None             A
# 11  serjeant  serjeant2008     None             A
# 12  serjeant  serjeant2008     None             A
# 13  serjeant  serjeant2008     None             A
# 14  serjeant  serjeant2008     None             A
# 15  serjeant  serjeant2008     None             A
# 16  serjeant  serjeant2009     None             A
# 17  serjeant  serjeant2009     None             A
# 18  serjeant  serjeant2009     None             A
# 19  serjeant  serjeant2009     None             A
# 21  serjeant  serjeant2011     None             A
# 22  serjeant  serjeant2012     None             A

# %%
in_df_2
# Out:
#     entry_#                                   SMILES pka_type  pka_value  \
# 0      2004                                       CO      pK1      15.50
# 1      2004                                       CO      pK1      15.09
# 2      2005                                      COO      pK1      11.50
# 3      2006                                       CS      pK1      10.33
# 4      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.14
# 5      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.06
# 6      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.05
# 7      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.23
# 8      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.17
# 9      2007  O=[N+]([O-])C([N+](=O)[O-])[N+](=O)[O-]      pK1       0.11
# 10     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.63
# 11     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.72
# 12     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.60
# 13     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.51
# 14     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.43
# 15     2008                O=[N+]([O-])C[N+](=O)[O-]      pK1       3.57
# 16     2009                            C[N+](=O)[O-]      pK1      10.45
# 17     2009                            C[N+](=O)[O-]      pK1      10.33
# 18     2009                            C[N+](=O)[O-]      pK1      10.21
# 19     2009                            C[N+](=O)[O-]      pK1      10.24
# 21     2011                                  NC(=S)S      pK1       2.95
#
#        T                            remarks method   assessment       ref  \
# 0   25.0                                NaN     C3    Uncertain        B8
# 1   25.0                                NaN    KIN    Uncertain      M126
# 2   20.0                                NaN     O5    Uncertain       E27
# 3   25.0  1% ethanol, gas solubility method    NaN    Uncertain       K57
# 4   20.0          In aqueous HClO4 Ho scale     O6    Uncertain      T58a
# 5   25.5                     Mixed constant     O5    Uncertain        H5
# 6    9.6                     Mixed constant     O5    Uncertain        H5
# 7    5.0            In aqueous HCl Ho scale     O6    Uncertain  N39, S82
# 8   20.0            In aqueous HCl Ho scale     O6    Uncertain  N39, S82
# 9   40.0            In aqueous HCl Ho scale     O6    Uncertain  N39, S82
# 10  20.0                             I=0.06     O5  Approximate       N39
# 11   5.0                             I=0.06     O5  Approximate       N39
# 12  20.0                             I=0.06     O5  Approximate       N39
# 13  40.0                             I=0.06     O5  Approximate       N39
# 14  60.0                             I=0.06     O5  Approximate       N39
# 15  25.0                             I=0.06     O5  Approximate        A7
# 16  10.0      C=0.005-0.017, mixed constant   E3bg  Approximate       T67
# 17  18.0      C=0.005-0.017, mixed constant   E3bg  Approximate       T67
# 18  25.0      C=0.005-0.017, mixed constant   E3bg  Approximate       T67
# 19  25.0      C=0.005-0.017, mixed constant   E3bg  Approximate       W22
# 21  25.0                       C=0.002-0.01     C2  Approximate        G4
#
#                                           ref_remarks  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   Thermodynamic quantities are derived from the ...
# 8   Thermodynamic quantities are derived from the ...
# 9   Thermodynamic quantities are derived from the ...
# 10  Thermodynamic quantities are derived from the ...
# 11  Thermodynamic quantities are derived from the ...
# 12  Thermodynamic quantities are derived from the ...
# 13  Thermodynamic quantities are derived from the ...
# 14  Thermodynamic quantities are derived from the ...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 21                                                NaN
#
#                                         entry_remarks  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   - 0.02  Thermodynamic quantities are derived f...
# 5   - 0.02  Thermodynamic quantities are derived f...
# 6   - 0.02  Thermodynamic quantities are derived f...
# 7   - 0.02  Thermodynamic quantities are derived f...
# 8   - 0.02  Thermodynamic quantities are derived f...
# 9   - 0.02  Thermodynamic quantities are derived f...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 21                                                NaN
#
#             original_IUPAC_names original_IUPAC_nicknames  \
# 0                       Methanol                      NaN
# 1                       Methanol                      NaN
# 2           Methyl hydroperoxide                      NaN
# 3                   Methanethiol                      NaN
# 4             methane, trinitro-                      NaN
# 5             methane, trinitro-                      NaN
# 6             methane, trinitro-                      NaN
# 7             methane, trinitro-                      NaN
# 8             methane, trinitro-                      NaN
# 9             methane, trinitro-                      NaN
# 10             methane, dinitro-                      NaN
# 11             methane, dinitro-                      NaN
# 12             methane, dinitro-                      NaN
# 13             methane, dinitro-                      NaN
# 14             methane, dinitro-                      NaN
# 15             methane, dinitro-                      NaN
# 16               methane, nitro-                      NaN
# 17               methane, nitro-                      NaN
# 18               methane, nitro-                      NaN
# 19               methane, nitro-                      NaN
# 21  methanedithioic acid, amino-      Dithiocarbamic acid
#
#                                     name_contributors  num_name_contributors  \
# 0     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 1     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 2     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 3     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 4     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 5     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 6     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 7     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 8     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 9     ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 10    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 11    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 12    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 13    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 14    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 15    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 16    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 17    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 18    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 19    ['opsin_name1', 'cirpy_name1', 'pubchem_name1']                    3.0
# 21  ['opsin_name1', 'opsin_nickname1', 'pubchem_ni...                    3.0
#
#       source     unique_ID pressure acidity_label
# 0   serjeant  serjeant2004     None             A
# 1   serjeant  serjeant2004     None             A
# 2   serjeant  serjeant2005     None             A
# 3   serjeant  serjeant2006     None             A
# 4   serjeant  serjeant2007     None             A
# 5   serjeant  serjeant2007     None             A
# 6   serjeant  serjeant2007     None             A
# 7   serjeant  serjeant2007     None             A
# 8   serjeant  serjeant2007     None             A
# 9   serjeant  serjeant2007     None             A
# 10  serjeant  serjeant2008     None             A
# 11  serjeant  serjeant2008     None             A
# 12  serjeant  serjeant2008     None             A
# 13  serjeant  serjeant2008     None             A
# 14  serjeant  serjeant2008     None             A
# 15  serjeant  serjeant2008     None             A
# 16  serjeant  serjeant2009     None             A
# 17  serjeant  serjeant2009     None             A
# 18  serjeant  serjeant2009     None             A
# 19  serjeant  serjeant2009     None             A
# 21  serjeant  serjeant2011     None             A

# %%
out_df
# Out:
#     entry_# SMILES pka_type  pka_value   T      remarks method assessment  \
# 20     2010    NaN      pK1       8.65 NaN  I=0.2(NaCl)   E3bg  Uncertain
#
#     ref ref_remarks entry_remarks    original_IUPAC_names  \
# 20  C72         NaN           NaN  Methanohydroxamic acid
#
#    original_IUPAC_nicknames name_contributors  num_name_contributors  \
# 20     Formohydroxamic acid               NaN                    NaN
#
#       source     unique_ID pressure acidity_label
# 20  serjeant  serjeant2010     None             A

# %%
in_df.to_csv("SAMPLE_in.csv",index=False)
in_df_2.to_csv("SAMPLE_in-high-confidence.csv",index=False)
out_df.to_csv("SAMPLE_rejected.csv",index=False)
